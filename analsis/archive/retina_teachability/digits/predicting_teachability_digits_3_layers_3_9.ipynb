# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime as dt
import os
from analsis.analsis_utils.plot_utils import plot_two_metrics, plot_two_metrics_vs_colored_metric, \
    plot_binned_metric_vs_mean_metric, plot_two_metrics_by_ephoc, plot_two_metrics_with_mean, \
    plot_two_metrics_with_mean_multi_ep, plot_two_metrics_by_ephoc, plot_two_ann_metrics_train_test, \
    plot_two_ann_metrics_begining_end, plot_mean_r2_bars, plot_hist_of_performances_by_ephoc,plot_ann_metric_train_test
import joblib

COLORS = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897', '#f6bd60', '#e76f51', '#2a9d8f', "#c77dff", "#f7d6e0"]
COLORS_20 = ["#adb5bd", "#7ec4cf", '#4F6272', "#3de0fe", "#c77dff", '#B7C3F3', '#2d6a4f', '#2a9d8f', '#8EB897',
             '#9a8c98',
             '#f6bd60', '#8a5a44', "#ede7b1", "#ff9505", '#e29578', '#f5cac3', "#f7d6e0", '#DD7596', '#DD7596',
             "#8c2f39", "#d0ee11",
             ]
COLORS_16 = ["#adb5bd", '#4F6272', "#c77dff", '#B7C3F3', '#2d6a4f', '#2a9d8f', '#8EB897', '#9a8c98',
             '#f6bd60', "#ede7b1", '#e29578', '#f5cac3', "#f7d6e0", '#DD7596', '#DD7596', "#8c2f39"]

# %%
task = "digits"
num_layers = '3'
dims = [64,3,9, 10]
_, dim1,dim2, _ = dims

results_path = f"/Volumes/noamaz/modularity/{task}/"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'

time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")
folder_name = f"{task}_{num_layers}_layers_{dim1}_{dim2}"
plot_path = f"{local_base_path}/plots/{task}_multi_arch/{folder_name}"

# %%
res_folder = f"{results_path}/{folder_name}/first_analysis_results"
# Out:
# 'digits_3_layers_8_4'

# %%
first_analsis = pd.read_csv(f"{res_folder}/2023-09-09-11-50-13_all_results_from_teach_archs_results_with_motifs_2000_ep.csv")
first_analsis.drop_duplicates([
            'num_connections',
            'entropy',
            'normed_entropy',
            'connectivity_ratio',
            'num_neurons',
                'neurons_in_layer_0',
                'neurons_in_layer_1',
                'neurons_in_layer_2',
                'max_possible_connections',
                'motifs_count_0',
                'motifs_count_1',
                'motifs_count_2',]).shape
# Out:
# (19594, 28)

# %%
res_folder = f"{results_path}/{folder_name}/first_analysis_results"
epochs = []
all_first_analsis = []
for file_name in sorted(os.listdir(res_folder)):
    ep = int(file_name.split('_')[-2])
    epochs.append(ep)
    first_analsis = pd.read_csv(f"{res_folder}/{file_name}")
    all_first_analsis.append(first_analsis.rename(
        columns={'connectivity_ratio': 'density',
                 }).sort_values('mean_performance', ascending=False)
                             )

# %%
all_first_analsis = [x for _, x in sorted(zip(epochs, all_first_analsis))]
epochs = sorted(epochs)

# %%
x_metric_name, y_metric_name = ('density', 'mean_performance')
plot_two_metrics_with_mean_multi_ep(
    x_metric_name=x_metric_name,
    y_metric_name=y_metric_name,
    all_result_df=all_first_analsis,
    epochs=epochs,
    task=task,
    time_str=time_str,
    plot_path=plot_path,
    name_addition=f'_multi_archs',
    title_addition=f'{num_layers} Layers, ',
    mark_size=0.8,
    color_ind=1,
    dims=dims
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 x_metric_name, y_metric_name = ('density', 'mean_performance')
# ----> 2 plot_two_metrics_with_mean_multi_ep(
#       3     x_metric_name=x_metric_name,
#       4     y_metric_name=y_metric_name,
#       5     all_result_df=all_first_analsis,
#       6     epochs=epochs,
#       7     task=task,
#       8     time_str=time_str,
#       9     plot_path=plot_path,
#      10     name_addition=f'_multi_archs',
#      11     title_addition=f'{num_layers} Layers, ',
#      12     mark_size=0.8,
#      13     color_ind=1,
#      14     dims=dims
#      15 )
#
# File ~/PycharmProjects/network_modularity/analsis/analsis_utils/plot_utils.py:1025, in plot_two_metrics_with_mean_multi_ep(x_metric_name, y_metric_name, all_result_df, epochs, dims, time_str, task, color_ind, plot_path, name_addition, title_addition, mark_size)
#    1022 plt.suptitle(f"{x_metric_name.replace('_', ' ')} of an architecture and its"
#    1023              f" {y_metric_name.replace('_', ' ')}, {dims} {title_addition}{task}", wrap=True)
#    1024 plt.tight_layout()
# -> 1025 plt.savefig(
#    1026     f"{plot_path}/{time_str}_{task}{name_addition}_{y_metric_name}_vs_{x_metric_name}.png")
#    1027 plt.show()
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/pyplot.py:979, in savefig(*args, **kwargs)
#     976 @_copy_docstring_and_deprecators(Figure.savefig)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/figure.py:3046, in Figure.savefig(self, fname, transparent, **kwargs)
#    3042     for ax in self.axes:
#    3043         stack.enter_context(
#    3044             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3046 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:541, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     494 """
#     495 Write the figure to a PNG file.
#     496
#    (...)
#     538     *metadata*, including the default 'Software' key.
#     539 """
#     540 FigureCanvasAgg.draw(self)
# --> 541 mpl.image.imsave(
#     542     filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/image.py:1675, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673 pil_kwargs.setdefault("format", format)
#    1674 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/PIL/Image.py:2317, in Image.save(self, fp, format, **params)
#    2315         fp = builtins.open(filename, "r+b")
#    2316     else:
# -> 2317         fp = builtins.open(filename, "w+b")
#    2319 try:
#    2320     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/noamazmon/PycharmProjects/network_modularity/plots/digits_multi_arch/digits_3_layers_3_9/2023-09-09-16-49-20_digits_multi_archs_mean_performance_vs_density.png'

# %%
plot_two_metrics_by_ephoc(
    x_metric_name=x_metric_name,
    y_metric_name=y_metric_name,
    all_result_df=all_first_analsis,
    epochs=epochs,
    task=task,
    time_str=time_str,
    plot_path=plot_path,
    title_addition=f'{num_layers} Layers, ',
    dims=dims,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_two_metrics_by_ephoc(
#       2     x_metric_name=x_metric_name,
#       3     y_metric_name=y_metric_name,
#       4     all_result_df=all_first_analsis,
#       5     epochs=epochs,
#       6     task=task,
#       7     time_str=time_str,
#       8     plot_path=plot_path,
#       9     title_addition=f'{num_layers} Layers, ',
#      10     dims=dims,
#      11 )
#
# File ~/PycharmProjects/network_modularity/analsis/analsis_utils/plot_utils.py:1135, in plot_two_metrics_by_ephoc(x_metric_name, y_metric_name, all_result_df, epochs, dims, time_str, task, plot_path, name_addition, title_addition, legend_title)
#    1132 plt.xlabel(f"{x_metric_name.replace('_', ' ')}")
#    1133 plt.title(f"{x_metric_name.replace('_', ' ')} of an architecture and its"
#    1134           f" mean {y_metric_name.replace('_', ' ')}, {dims} {title_addition}{task}", wrap=True)
# -> 1135 plt.savefig(
#    1136     f"{plot_path}/{time_str}_{y_metric_name}_by_ephoc{name_addition}.png")
#    1137 plt.show()
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/pyplot.py:979, in savefig(*args, **kwargs)
#     976 @_copy_docstring_and_deprecators(Figure.savefig)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/figure.py:3046, in Figure.savefig(self, fname, transparent, **kwargs)
#    3042     for ax in self.axes:
#    3043         stack.enter_context(
#    3044             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3046 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:541, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     494 """
#     495 Write the figure to a PNG file.
#     496
#    (...)
#     538     *metadata*, including the default 'Software' key.
#     539 """
#     540 FigureCanvasAgg.draw(self)
# --> 541 mpl.image.imsave(
#     542     filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/image.py:1675, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673 pil_kwargs.setdefault("format", format)
#    1674 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/PIL/Image.py:2317, in Image.save(self, fp, format, **params)
#    2315         fp = builtins.open(filename, "r+b")
#    2316     else:
# -> 2317         fp = builtins.open(filename, "w+b")
#    2319 try:
#    2320     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/noamazmon/PycharmProjects/network_modularity/plots/digits_multi_arch/digits_3_layers_3_9/2023-09-09-16-49-20_mean_performance_by_ephoc.png'

# %%
plot_hist_of_performances_by_ephoc(
    metric_name='mean_performance',
    all_result_df=all_first_analsis,
    epochs=epochs,
    task=task,
    time_str=time_str,
    plot_path=plot_path,
    title_addition=f'{num_layers} Layers, ',
    dims=dims,
    bins=100,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plot_hist_of_performances_by_ephoc(
#       2     metric_name='mean_performance',
#       3     all_result_df=all_first_analsis,
#       4     epochs=epochs,
#       5     task=task,
#       6     time_str=time_str,
#       7     plot_path=plot_path,
#       8     title_addition=f'{num_layers} Layers, ',
#       9     dims=dims,
#      10     bins=100,
#      11 )
#
# File ~/PycharmProjects/network_modularity/analsis/analsis_utils/plot_utils.py:1235, in plot_hist_of_performances_by_ephoc(metric_name, all_result_df, epochs, dims, time_str, task, plot_path, name_addition, title_addition, bins)
#    1233 plt.tight_layout()
#    1234 if plot_path:
# -> 1235     plt.savefig(
#    1236         f"{plot_path}/{time_str}_hist_of_{metric_name}_by_ephoc{name_addition}.png")
#    1237 plt.show()
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/pyplot.py:979, in savefig(*args, **kwargs)
#     976 @_copy_docstring_and_deprecators(Figure.savefig)
#     977 def savefig(*args, **kwargs):
#     978     fig = gcf()
# --> 979     res = fig.savefig(*args, **kwargs)
#     980     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     981     return res
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/figure.py:3046, in Figure.savefig(self, fname, transparent, **kwargs)
#    3042     for ax in self.axes:
#    3043         stack.enter_context(
#    3044             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3046 self.canvas.print_figure(fname, **kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/_api/deprecation.py:415, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     405     deprecation_addendum = (
#     406         f"If any parameter follows {name!r}, they should be passed as "
#     407         f"keyword, not positionally.")
#     408     warn_deprecated(
#     409         since,
#     410         name=repr(name),
#    (...)
#     413                  else deprecation_addendum,
#     414         **kwargs)
# --> 415 return func(*inner_args, **inner_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:541, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     494 """
#     495 Write the figure to a PNG file.
#     496
#    (...)
#     538     *metadata*, including the default 'Software' key.
#     539 """
#     540 FigureCanvasAgg.draw(self)
# --> 541 mpl.image.imsave(
#     542     filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543     dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/matplotlib/image.py:1675, in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1673 pil_kwargs.setdefault("format", format)
#    1674 pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1675 image.save(fname, **pil_kwargs)
#
# File /opt/anaconda3/envs/network_modularity/lib/python3.9/site-packages/PIL/Image.py:2317, in Image.save(self, fp, format, **params)
#    2315         fp = builtins.open(filename, "r+b")
#    2316     else:
# -> 2317         fp = builtins.open(filename, "w+b")
#    2319 try:
#    2320     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/noamazmon/PycharmProjects/network_modularity/plots/digits_multi_arch/digits_3_layers_8_4/2023-09-09-10-20-06_hist_of_mean_performance_by_ephoc.png'

# %%
# Out:
# 4

# %%
ann_reg_res_folder = f"/Volumes/noamaz/modularity/digits/digits_{num_layers}_layers_{dim1}/teach_archs_regression_results"
epochs = [10000]
all_ann_reg_res = []
# files_names = [f for f in sorted(os.listdir(ann_reg_res_folder) if '.csv' in f]
files_names = [
'digits_2023-09-07-13-49-50_lr_0.001_bs_512_output_10k_ep_adj_False_meta_True_2k_ephoc.csv',
    'digits_2023-09-07-13-49-50_lr_0.005_bs_512_output_10k_ep_adj_False_meta_True_2k_ephoc.csv',
]
lr = ['0.001', '0.005']
for file_name in files_names:
    ann_reg_res = pd.read_csv(f"{ann_reg_res_folder}/{file_name}").rename(columns={"losses": "losses train", })
    all_ann_reg_res.append(ann_reg_res)

# %%
#all_ann_reg_res = [x for _, x in sorted(zip(epochs, all_ann_reg_res))]
#epochs = sorted(epochs)

# %%
plot_two_ann_metrics_begining_end(
    x_metric_name='Epoch',
    y_metric_name='losses train',
    all_result_list=all_ann_reg_res,
    epochs=lr,
    dims=dims,
    time_str=time_str,
    task=task,
    plot_path=plot_path,
    title_addition=f'{num_layers} layers',
    time_split_ind=20,
    jump=20,
    legend_title='lr'
)

# %%
plot_ann_metric_train_test(
x_metric_name = 'Epoch',
y_metric_name = 'r2s',
all_result_list = all_ann_reg_res,
epochs = lr,
dims = dims,
time_str = time_str,
task = task,
plot_path = plot_path,
title_addition = f'{num_layers} layers',
start_ind = 20,
jump = 25,
legend_title = 'lr',
)

# %%
plot_two_ann_metrics_train_test(
    x_metric_name='Epoch',
    y_up_metric_name='losses',
    y_down_metric_name='r2s',
    result=all_ann_reg_res[0].rename(columns={"losses": "losses train", }),
    dims=dims,
    time_str=time_str,
    task=task,
    plot_path=plot_path,
    title_addition=f'{num_layers} layers',
    start_ind=10,
    jump=100,
)
