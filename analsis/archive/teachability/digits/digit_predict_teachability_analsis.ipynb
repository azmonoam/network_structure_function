# %%
from datetime import datetime as dt

import pandas as pd

from analsis.analsis_utils.plot_utils import plot_prediction_zoom, plot_prediction_final_r2

COLORS = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897', '#f6bd60', '#e76f51', '#2a9d8f']

base_path = '/Users/noamazmon/PycharmProjects/network_modularity'

# %%
# /// DIGITS - 0.001 ///

# %%
base_path = '/Volumes/noamaz/modularity'
res_folder = f"{base_path}/teach_archs/digits/digits_teach_archs_regression_results"
path_all = f"{res_folder}/digits_2023-06-26-16-33-26_lr_0.001_bs_512_output.csv"
path_adj_only = f"{res_folder}/digits_2023-06-26-16-37-22_lr_0.001_bs_512_output_adj_only.csv"
path_meta_only = f"{res_folder}/digits_2023-06-26-16-25-22_lr_0.001_bs_512_output_meta_only.csv"
out_path = f"plots/digits_predict_teacability"
lr = 0.001
task = 'digits'
results_all = pd.read_csv(path_all)
results_adj_only = pd.read_csv(path_adj_only)
results_meta_only = pd.read_csv(path_meta_only)

# %%
base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    task=task,
    lr=lr,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction.png",
    cut=200,
    on_end=False,
)

# %%
lr = 0.001
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=10,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_begining.png",
    on_end=False,
)

# %%
plot_prediction_final_r2(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=50,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_final_prediction.png",
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=50,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_end.png",
    on_end=True,
)

# %%
# /// DIGITS - 0.005 ///

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/digits/digits_teach_archs_regression_results"
path_all = f"{res_folder}/digits_2023-06-26-16-37-42_lr_0.005_bs_512_output.csv"
path_adj_only = f"{res_folder}/digits_2023-06-26-16-33-37_lr_0.005_bs_512_output_adj_only.csv"
path_meta_only = f"{res_folder}/digits_2023-06-26-16-25-22_lr_0.005_bs_512_output_meta_only.csv"
out_path = f"plots/digits_predict_teacability"
lr = 0.005
results_all = pd.read_csv(path_all)
results_adj_only = pd.read_csv(path_adj_only)
results_meta_only = pd.read_csv(path_meta_only)

# %%
base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    task=task,
    lr=lr,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction.png",
    cut=200,
    on_end=False,
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=10,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_begining.png",
    on_end=False,
)

# %%
plot_prediction_final_r2(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=70,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_final_prediction.png",
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=50,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_end.png",
    on_end=True,
)
