# %%
from datetime import datetime as dt

import pandas as pd

from analsis.analsis_utils.plot_utils import plot_all_num_features_models, plot_loss_and_r2s_for_selected_feature_numbers, \
    plot_num_features_vs_r2, plot_bar_plot_of_used_features, plot_r2_vs_num_features
from analsis.analsis_utils.utils import get_all_num_features_results

# %%
exp_name = 'exp_2023-04-25-12-22-31'
base_path = '/Volumes/noamaz/modularity'
res_folder = f"{base_path}/teach_archs/retina/retina_lightgbm_feature_selection/{exp_name}/teach_archs_regression_feature_selection_results/2023-05-22-11-35_500_eph"
used_features_csv_path = f"{base_path}/teach_archs/retina/retina_lightgbm_feature_selection/{exp_name}/2023-05-04-12-30-24_used_features.csv"
preformence_vs_features_csv_path = f"{base_path}/teach_archs/retina/retina_lightgbm_feature_selection/{exp_name}/2023-05-04-12-30-24_feature_selection.csv"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")
fig_out_folder = f"retina_lightgbm_feature_selection/{exp_name}"
lr = 0.001
task = "retina"

# %%
start_idx=200
end_idx=1000
all_results_dict, res_df_200_1000 = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=start_idx,
    end_idx=end_idx
)

# %%
#res_df.to_csv(f"{res_folder}/{time_str}_feature_selection_final_{end_cut}.csv", )

# %%
start_idx=200
end_idx=1000
plot_num_features_vs_r2(
    res_df=res_df_200_1000,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
)

# %%
start_idx=200
end_idx=1000
plot_num_features_vs_r2(
    res_df=res_df_200_1000,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
)
# Out:
#     num_features  mean_train_r2  mean_test_r2  max_train_r2  max_test_r2
# 2              1       0.552201      0.546277      0.562029     0.571797
# 8              5       0.924403      0.922852      0.930195     0.933095
# 17            10       0.968317      0.956609      0.976469     0.968422
# 1             15       0.975163      0.966886      0.982146     0.976025
# 3             20       0.978743      0.971175      0.986188     0.979233
# 10            25       0.980245      0.970556      0.989046     0.980634
# 5             30       0.983125      0.971785      0.991374     0.979982
# 9             35       0.985084      0.969640      0.992479     0.977345
# 6             40       0.984308      0.967178      0.992913     0.975618
# 13            45       0.985491      0.967418      0.993845     0.975243
# 16            50       0.986714      0.964463      0.994292     0.973706
# 4             55       0.987435      0.964442      0.994969     0.972160
# 12            60       0.987032      0.963213      0.995039     0.972438
# 11            65       0.987934      0.963471      0.995417     0.970924
# 15            70       0.988386      0.963990      0.995402     0.971452
# 0             75       0.989589      0.967929      0.995689     0.974791
# 7             80       0.985678      0.969468      0.993350     0.977531
# 14            85       0.985036      0.971964      0.992030     0.978959

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='losses',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)
# Out:
#     Unnamed: 0  num_features  train_r2   test_r2  \
# 0           17             1  0.617769  0.603766
# 1            0             5  0.935851  0.929582
# 2            1            10  0.973266  0.968640
# 3            2            15  0.979038  0.974932
# 4            3            20  0.981651  0.977990
# 5            4            25  0.981978  0.978193
# 6            5            30  0.982202  0.978562
# 7            6            35  0.982420  0.979019
# 8            8            40  0.982499  0.979177
# 9            7            45  0.982474  0.979206
# 10           9            50  0.982548  0.979128
# 11          16            55  0.982645  0.979259
# 12          15            60  0.982599  0.979106
# 13          10            65  0.982556  0.979112
# 14          11            70  0.982568  0.979098
# 15          13            75  0.982577  0.979150
# 16          14            80  0.982577  0.979150
# 17          12            85  0.982577  0.979150
#
#                                            model_name
# 0      2023-05-04-12-30-24_masked_data_1_features.pkl
# 1   /Volumes/noamaz/modularity/teach_archs/retina/...
# 2   /Volumes/noamaz/modularity/teach_archs/retina/...
# 3   /Volumes/noamaz/modularity/teach_archs/retina/...
# 4   /Volumes/noamaz/modularity/teach_archs/retina/...
# 5   /Volumes/noamaz/modularity/teach_archs/retina/...
# 6   /Volumes/noamaz/modularity/teach_archs/retina/...
# 7   /Volumes/noamaz/modularity/teach_archs/retina/...
# 8   /Volumes/noamaz/modularity/teach_archs/retina/...
# 9   /Volumes/noamaz/modularity/teach_archs/retina/...
# 10  /Volumes/noamaz/modularity/teach_archs/retina/...
# 11  /Volumes/noamaz/modularity/teach_archs/retina/...
# 12  /Volumes/noamaz/modularity/teach_archs/retina/...
# 13  /Volumes/noamaz/modularity/teach_archs/retina/...
# 14  /Volumes/noamaz/modularity/teach_archs/retina/...
# 15  /Volumes/noamaz/modularity/teach_archs/retina/...
# 16  /Volumes/noamaz/modularity/teach_archs/retina/...
# 17  /Volumes/noamaz/modularity/teach_archs/retina/...

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='log loss',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)
# Out:
# 0.9905238978726348

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s test',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)
# Out:
# 0.9524454572008096

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s train',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)
# Out:
# 0.9830276107489818

# %%
start_idx=800
end_idx=1000
all_results_dict, res_df_800_1000 = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=start_idx,
    end_idx=end_idx
)

# %%
start_idx=800
end_idx=1000
plot_num_features_vs_r2(
    res_df=res_df_800_1000,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
)

# %%
start_idx=800
end_idx=1000
plot_num_features_vs_r2(
    res_df=res_df_800_1000,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
)

# %%
desiered_num_features = [85, 30, 25, 20, 75]
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=25,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=50,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=15,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
desiered_num_features = [85, 10, 15, 30]
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=12,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
used_features_df = pd.read_csv(used_features_csv_path).drop("Unnamed: 0", axis=1).rename(columns={'connectivity_ratio': 'density'})
sum_uses = used_features_df.sum().sort_index().sort_values(ascending=False)

# %%
cut = 15
is_top = True
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=is_top,
)

# %%
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=False,
)

# %%
preformence_vs_features_res_df = pd.read_csv(preformence_vs_features_csv_path).drop("Unnamed: 0", axis=1)
plot_r2_vs_num_features(
        res_df=preformence_vs_features_res_df,
        plots_folder=fig_out_folder,
        local_base_path=local_base_path,
        time_str=time_str,
        task=task,
)
