# %%
from datetime import datetime as dt
from analsis.analsis_utils.plot_utils import plot_binned_metric_vs_mean_metric, plot_3d_three_metrices_vs_mean_metric, plot_two_binned_metrices_vs_third_means_metrics_colors
import pandas as pd

# %%
results_path = "/Volumes/noamaz/modularity/teach_archs/retina/"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
results_csv_name = "2023-04-13-16-23-07_all_results_from_retina_teach_archs_results.csv"
results = pd.read_csv(f"{results_path}/{results_csv_name}")
mean_metric_name = "max_performance"
task = "retina"
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_binned_metric_vs_mean_metric(
    metric_name="modularity",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=2,
    local_base_path=local_base_path,
)

# %%
plot_binned_metric_vs_mean_metric(
    metric_name="connectivity_ratio",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=1,
    local_base_path=local_base_path,
    plot_error_bars=True
)

# %%
plot_binned_metric_vs_mean_metric(
    metric_name="normed_entropy",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=3,
    local_base_path=local_base_path,
)

# %%
plot_3d_three_metrices_vs_mean_metric(
    metric_names=["modularity", "connectivity_ratio", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    local_base_path=local_base_path,
)

# %%
plot_two_binned_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Reds",
    local_base_path=local_base_path,
)

# %%
plot_two_binned_metrices_vs_third_means_metrics_colors(
    metric_names=["connectivity_ratio", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Greens",
    local_base_path=local_base_path,
)

# %%
plot_two_binned_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "connectivity_ratio"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Blues",
    local_base_path=local_base_path,
)

# %%
mean_metric_name = "mean_performance"

# %%
plot_binned_metric_vs_mean_metric(
    metric_name="modularity",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=2,
    local_base_path=local_base_path,
)

# %%
plot_binned_metric_vs_mean_metric(
    metric_name="connectivity_ratio",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=1,
    local_base_path=local_base_path,
)

# %%
plot_binned_metric_vs_mean_metric(
    metric_name="normed_entropy",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=3,
    local_base_path=local_base_path,
)

# %%
plot_3d_three_metrices_vs_mean_metric(
    metric_names=["modularity", "connectivity_ratio", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    local_base_path=local_base_path,
)

# %%
plot_two_binned_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Reds",
    local_base_path=local_base_path,
)

# %%
plot_two_binned_metrices_vs_third_means_metrics_colors(
    metric_names=["connectivity_ratio", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Greens",
    local_base_path=local_base_path,
)

# %%
plot_two_binned_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "connectivity_ratio"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Blues",
    local_base_path=local_base_path,
)
