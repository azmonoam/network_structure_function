# %%
from datetime import datetime as dt
from analsis.analsis_utils.plot_utils import plot_metric_vs_mean_metric, plot_3d_three_metrices_vs_mean_metric, plot_two_metrices_vs_third_means_metrics_colors
import pandas as pd

# %%
results_path = "/Volumes/noamaz/modularity/teach_archs/retina/"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
results_csv_name = "2023-04-13-16-23-07_all_results_from_retina_teach_archs_results.csv"
results = pd.read_csv(f"{results_path}/{results_csv_name}")
mean_metric_name = "max_performance"
task = "retina"
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_metric_vs_mean_metric(
    metric_name="modularity",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=2,
    local_base_path=local_base_path,
)

# %%
plot_metric_vs_mean_metric(
    metric_name="connectivity_ratio",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=1,
    local_base_path=local_base_path,
    plot_error_bars=True
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_metric_vs_mean_metric(
#       2     metric_name="connectivity_ratio",
#       3     mean_metric_name=mean_metric_name,
#       4     result_df=results,
#       5     time_str=time_str,
#       6     task=task,
#       7     color_ind=1,
#       8     local_base_path=local_base_path,
#       9     plot_error_bars=True
#      10 )
#
# TypeError: plot_metric_vs_mean_metric() got an unexpected keyword argument 'plot_error_bars'

# %%
plot_metric_vs_mean_metric(
    metric_name="normed_entropy",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=3,
    local_base_path=local_base_path,
)

# %%
plot_3d_three_metrices_vs_mean_metric(
    metric_names=["modularity", "connectivity_ratio", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Reds",
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_vs_third_means_metrics_colors(
    metric_names=["connectivity_ratio", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Greens",
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "connectivity_ratio"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Blues",
    local_base_path=local_base_path,
)

# %%
mean_metric_name = "mean_performance"

# %%
plot_metric_vs_mean_metric(
    metric_name="modularity",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=2,
    local_base_path=local_base_path,
)

# %%
plot_metric_vs_mean_metric(
    metric_name="connectivity_ratio",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=1,
    local_base_path=local_base_path,
)

# %%
plot_metric_vs_mean_metric(
    metric_name="normed_entropy",
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=3,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Reds",
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_vs_third_means_metrics_colors(
    metric_names=["connectivity_ratio", "normed_entropy"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Greens",
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_vs_third_means_metrics_colors(
    metric_names=["modularity", "connectivity_ratio"],
    mean_metric_name=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme="Blues",
    local_base_path=local_base_path,
)

# %%
results_path = "/Volumes/noamaz/modularity/teach_archs/retina/"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
results_csv_name = "2023-04-13-16-23-07_all_results_from_retina_teach_archs_results.csv"
full_results_csv_name = "2023-04-18-12-19-46_all_extended_results_from_retina_teach_archs_results.csv"
results = pd.read_csv(f"{results_path}/{full_results_csv_name}")
top_results = results[results[mean_metric_name] >= results[mean_metric_name].quantile(0.9)]

# %%
plot_metric_vs_mean_metric(
    metric_name="connectivity_ratio",
    mean_metric_name='total_connectivity_ratio_between_layers_1',
    result_df=results,
    time_str=time_str,
    task=task,
    color_ind=1,
    local_base_path=local_base_path,
)
