# %%
from datetime import datetime as dt

import pandas as pd

from analsis.analsis_utils.plot_utils import plot_prediction_zoom, plot_prediction_final_r2

COLORS = ['#4F6272', '#B7C3F3', '#DD7596', '#8EB897', '#f6bd60', '#e76f51', '#2a9d8f']

base_path = '/Users/noamazmon/PycharmProjects/network_modularity'

# %%
# /// XOR - 0.001 ///

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/xors/xor_teach_archs_regression_results"
path_all = f"{res_folder}/xor_2023-04-13-14-44-00_lr_0.001_bs_512_output.csv"
path_adj_only = f"{res_folder}/xor_2023-04-13-14-44-00_lr_0.001_bs_512_output_adj_only.csv"
path_meta_only = f"{res_folder}/xor_2023-04-13-14-44-00_lr_0.001_bs_512_output_meta_only.csv"
out_path = f"plots/xor_predict_teacability"
lr = 0.001
task = 'xor'
results_all = pd.read_csv(path_all)
results_adj_only = pd.read_csv(path_adj_only)
results_meta_only = pd.read_csv(path_meta_only)

# %%
base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    task=task,
    lr=lr,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction.png",
    cut=200,
    on_end=False,
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=10,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_begining.png",
    on_end=False,
)

# %%
plot_prediction_final_r2(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=200,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_final_prediction.png",
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=50,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_end.png",
    on_end=True,
)

# %%
# /// XOR - 0.005 ///

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/xors/xor_teach_archs_regression_results"
path_all = f"{res_folder}/xor_2023-04-13-14-44-00_lr_0.005_bs_512_output.csv"
path_adj_only = f"{res_folder}/xor_2023-04-13-14-44-35_lr_0.005_bs_512_output_adj_only.csv"
path_meta_only = f"{res_folder}/xor_2023-04-13-14-44-00_lr_0.005_bs_512_output_meta_only.csv"
out_path = f"plots/xor_predict_teacability"
lr = 0.005
results_all = pd.read_csv(path_all)
results_adj_only = pd.read_csv(path_adj_only)
results_meta_only = pd.read_csv(path_meta_only)

# %%
base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    task=task,
    lr=lr,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction.png",
    cut=200,
    on_end=False,
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=10,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_begining.png",
    on_end=False,
)

# %%
plot_prediction_final_r2(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=200,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_final_prediction.png",
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=50,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_end.png",
    on_end=True,
)

# %%
# /// RETINA - 0.001 ///

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/retina/retina_teach_archs_regression_results"
path_all = f"{res_folder}/retina_2023-04-16-15-21-02_lr_0.001_bs_512_output.csv"
path_adj_only = f"{res_folder}/retina_2023-04-16-15-19-38_lr_0.001_bs_512_output_adj_only.csv"
path_meta_only = f"{res_folder}/retina_2023-04-16-15-19-38_lr_0.001_bs_512_output_meta_only.csv"
out_path = f"plots/retina_predict_teacability"
lr = 0.001
task = "retina"
results_all = pd.read_csv(path_all)
results_adj_only = pd.read_csv(path_adj_only)
results_meta_only = pd.read_csv(path_meta_only)

# %%
base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    task=task,
    lr=lr,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction.png",
    cut=200,
    on_end=False,
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=10,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_begining.png",
    on_end=False,
)

# %%
plot_prediction_final_r2(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=200,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_final_prediction.png",
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=50,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_end.png",
    on_end=True,
)

# %%
# /// RETINA - 0.005 ///

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/retina/retina_teach_archs_regression_results"
path_all = f"{res_folder}/retina_2023-04-16-15-19-51_lr_0.005_bs_512_output.csv"
path_adj_only = f"{res_folder}/retina_2023-04-16-15-19-51_lr_0.005_bs_512_output_adj_only.csv"
path_meta_only = f"{res_folder}/retina_2023-04-16-15-19-51_lr_0.005_bs_512_output_meta_only.csv"
out_path = f"plots/retina_predict_teacability"
lr = 0.005
task = "retina"
results_all = pd.read_csv(path_all)
results_adj_only = pd.read_csv(path_adj_only)
results_meta_only = pd.read_csv(path_meta_only)

# %%
base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    task=task,
    lr=lr,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction.png",
    cut=200,
    on_end=False,
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=10,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_begining.png",
    on_end=False,
)

# %%
plot_prediction_final_r2(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=200,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_final_prediction.png",
)

# %%
plot_prediction_zoom(
    results_all=results_all,
    results_adj_only=results_adj_only,
    results_meta_only=results_meta_only,
    cut=50,
    lr=lr,
    task=task,
    out_path=f"{base_path}/{out_path}/{task}_{time_str}_lr_{lr}_teachability_prediction_zoom_on_end.png",
    on_end=True,
)
