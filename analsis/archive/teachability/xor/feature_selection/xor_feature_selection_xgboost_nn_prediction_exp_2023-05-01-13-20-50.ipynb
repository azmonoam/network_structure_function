# %%
from datetime import datetime as dt

import pandas as pd

from analsis.analsis_utils.plot_utils import plot_all_num_features_models, \
    plot_loss_and_r2s_for_selected_feature_numbers, \
    plot_num_features_vs_r2, plot_bar_plot_of_used_features, plot_r2_vs_num_features
from analsis.analsis_utils.utils import get_all_num_features_results

# %%
exp_name = "exp_2023-05-01-13-20-50"
base_path = '/Volumes/noamaz/modularity'
res_folder = f"{base_path}/teach_archs/xors/xor_xgboost_feature_selection/{exp_name}/teach_archs_regression_feature_selection_results/2023-05-22-11-35_500_eph"
used_features_csv_path = f"{base_path}/teach_archs/xors/xor_xgboost_feature_selection/{exp_name}/2023-05-01-13-20-50_used_features.csv"
preformence_vs_features_csv_path = f"{base_path}/teach_archs/xors/xor_xgboost_feature_selection/{exp_name}/2023-05-01-13-20-50_feature_selection.csv"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")
fig_out_folder = f"xor_xgboost_feature_selection/{exp_name}"
lr = 0.001
task = "xor"
regressor = 'XGboost'

# %%
start_idx = 200
end_idx = 1000
all_results_dict, res_df_200_1000 = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=start_idx,
    end_idx=end_idx
)
# Out:
# xors_2023-05-22-11-44-21_lr_0.001_bs_512_output_meta_only_15_features_model.pkl
# xors_2023-05-22-11-44-20_lr_0.001_bs_512_output_meta_only_1_features.csv
# xors_2023-05-22-11-44-21_lr_0.001_bs_512_output_meta_only_15_features.csv
# xors_2023-05-28-14-59-54_lr_0.001_bs_512_output_meta_only_96_features_model.pkl
# xors_2023-05-22-11-44-22_lr_0.001_bs_512_output_meta_only_35_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_85_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_80_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_95_features.csv
# xors_2023-05-28-14-43-30_lr_0.001_bs_512_output_meta_only_55_features.csv
# xors_2023-05-28-14-43-31_lr_0.001_bs_512_output_meta_only_70_features.csv
# xors_2023-05-22-11-44-23_lr_0.001_bs_512_output_meta_only_5_features_model.pkl
# xors_2023-05-28-14-43-31_lr_0.001_bs_512_output_meta_only_65_features_model.pkl
# ...

# %%
#res_df.to_csv(f"{res_folder}/{time_str}_feature_selection_final_{end_cut}.csv", )

# %%
start_idx = 200
end_idx = 1000
plot_num_features_vs_r2(
    res_df=res_df_200_1000,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
    regressor=regressor,
)

# %%
start_idx = 200
end_idx = 1000
plot_num_features_vs_r2(
    res_df=res_df_200_1000,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
    regressor=regressor,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='losses',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
    regressor=regressor,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='log loss',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
    regressor=regressor,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s test',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
    regressor=regressor,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s train',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
    regressor=regressor,
)

# %%
start_idx = 800
end_idx = 1000
all_results_dict, res_df_800_1000 = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=start_idx,
    end_idx=end_idx
)
# Out:
# xors_2023-05-22-11-44-21_lr_0.001_bs_512_output_meta_only_15_features_model.pkl
# xors_2023-05-22-11-44-20_lr_0.001_bs_512_output_meta_only_1_features.csv
# xors_2023-05-22-11-44-21_lr_0.001_bs_512_output_meta_only_15_features.csv
# xors_2023-05-28-14-59-54_lr_0.001_bs_512_output_meta_only_96_features_model.pkl
# xors_2023-05-22-11-44-22_lr_0.001_bs_512_output_meta_only_35_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_85_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_80_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_95_features.csv
# xors_2023-05-28-14-43-30_lr_0.001_bs_512_output_meta_only_55_features.csv
# xors_2023-05-28-14-43-31_lr_0.001_bs_512_output_meta_only_70_features.csv
# xors_2023-05-22-11-44-23_lr_0.001_bs_512_output_meta_only_5_features_model.pkl
# xors_2023-05-28-14-43-31_lr_0.001_bs_512_output_meta_only_65_features_model.pkl
# ...

# %%
start_idx = 800
end_idx = 1000
plot_num_features_vs_r2(
    res_df=res_df_800_1000,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
    regressor=regressor,
)

# %%
start_idx = 800
end_idx = 1000
plot_num_features_vs_r2(
    res_df=res_df_800_1000,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
    regressor=regressor,
)

# %%
start_idx = 950
end_idx = 1000
all_results_dict, res_df_950_1000 = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=start_idx,
    end_idx=end_idx
)
start_idx = 950
end_idx = 1000
plot_num_features_vs_r2(
    res_df=res_df_950_1000,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'last_{end_idx-start_idx}_ephocs',
    regressor=regressor,
)
# Out:
# xors_2023-05-22-11-44-21_lr_0.001_bs_512_output_meta_only_15_features_model.pkl
# xors_2023-05-22-11-44-20_lr_0.001_bs_512_output_meta_only_1_features.csv
# xors_2023-05-22-11-44-21_lr_0.001_bs_512_output_meta_only_15_features.csv
# xors_2023-05-28-14-59-54_lr_0.001_bs_512_output_meta_only_96_features_model.pkl
# xors_2023-05-22-11-44-22_lr_0.001_bs_512_output_meta_only_35_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_85_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_80_features.csv
# xors_2023-05-28-14-43-53_lr_0.001_bs_512_output_meta_only_95_features.csv
# xors_2023-05-28-14-43-30_lr_0.001_bs_512_output_meta_only_55_features.csv
# xors_2023-05-28-14-43-31_lr_0.001_bs_512_output_meta_only_70_features.csv
# xors_2023-05-22-11-44-23_lr_0.001_bs_512_output_meta_only_5_features_model.pkl
# xors_2023-05-28-14-43-31_lr_0.001_bs_512_output_meta_only_65_features_model.pkl
# ...

# %%
desiered_num_features = [85, 30, 25, 20, 75]
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=25,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
    regressor=regressor,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=50,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
    regressor=regressor,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=15,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
    regressor=regressor,
)

# %%
desiered_num_features = [85, 10, 15, 30]
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=12,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
    regressor=regressor,
)

# %%
used_features_df = pd.read_csv(used_features_csv_path).drop("Unnamed: 0", axis=1).rename(columns={'connectivity_ratio': 'density'})
sum_uses = used_features_df.sum().sort_index().sort_values(ascending=False)

# %%
cut = 15
is_top = True
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=is_top,
    regressor=regressor,
)

# %%
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=False,
    regressor=regressor,
)

# %%
preformence_vs_features_res_df = pd.read_csv(preformence_vs_features_csv_path).drop("Unnamed: 0", axis=1)
plot_r2_vs_num_features(
        res_df=preformence_vs_features_res_df,
        plots_folder=fig_out_folder,
        local_base_path=local_base_path,
        regressor=regressor,
        time_str=time_str,
        task=task,
)
