# %%
from datetime import datetime as dt

import pandas as pd

from analsis.analsis_utils.plot_utils import (
    rads,
    greens,
    blues,
    light_oranges,
    purples,
    pinks,
    grays,
    oranges,
    plot_two_metrices_top_and_bottom_quentiles,
)

# %%
results_path = "/Volumes/noamaz/modularity/teach_archs/xors"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
results_csv_name = "2023-04-10-17-25-10_all_results_from_xor_teach_archs_results.csv"
full_results_csv_name = "2023-04-18-12-16-02_all_extended_results_from_xor_teach_archs_results.csv"
results = pd.read_csv(f"{results_path}/{full_results_csv_name}")

# %%
results.columns
# Out:
# Index(['Unnamed: 0', 'exp_name', 'modularity', 'entropy', 'normed_entropy',
#        'num_connections', 'median_performance', 'mean_performance',
#        'max_performance', 'performance_std', 'connectivity_ratio',
#        'num_successes_1.0', 'success_percent_1.0',
#        'total_connectivity_ratio_between_layers_0',
#        'total_connectivity_ratio_between_layers_1',
#        'total_connectivity_ratio_between_layers_2',
#        'total_connectivity_ratio_between_layers_3',
#        'total_connectivity_ratio_between_layers_4',
#        'max_connectivity_between_layers_per_layer_0',
#        'max_connectivity_between_layers_per_layer_1',
#        'max_connectivity_between_layers_per_layer_2',
#        'max_connectivity_between_layers_per_layer_3',
#        'max_connectivity_between_layers_per_layer_4',
#        'layer_connectivity_rank_0', 'layer_connectivity_rank_1',
#        'layer_connectivity_rank_2', 'layer_connectivity_rank_3',
#        'layer_connectivity_rank_4',
# ...

# %%
mean_metric_name = "mean_performance"
task = "xor"
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["modularity", "normed_entropy"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=rads,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["connectivity_ratio", "normed_entropy"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=greens,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["modularity", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=blues,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["mean_num_paths_to_output_per_input_neuron", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=light_oranges,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["mean_distances_between_input_neuron", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=pinks,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["total_connectivity_ratio_between_layers_1", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=purples,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["total_connectivity_ratio_between_layers_0", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=purples,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["total_connectivity_ratio_between_layers_3", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=purples,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["max_connectivity_between_layers_per_layer_3", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=grays,
    local_base_path=local_base_path,
)

# %%
plot_two_metrices_top_and_bottom_quentiles(
    metric_names=["mean_num_involved_neurons_in_paths_per_input_neuron", "connectivity_ratio"],
    quantile_metric=mean_metric_name,
    result_df=results,
    time_str=time_str,
    task=task,
    color_scheme=oranges,
    local_base_path=local_base_path,
)
