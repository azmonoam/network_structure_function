# %%
from datetime import datetime as dt

import pandas as pd

from utils.plot_utils import plot_all_num_features_models, plot_loss_and_r2s_for_selected_feature_numbers, \
    plot_num_features_vs_r2, plot_bar_plot_of_used_features
from utils.utils import get_all_num_features_results

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/xors/xor_teach_archs_regression_feature_selection_results"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")
fig_out_folder = f"xor_regression_feature_selection"
lr = 0.001
task = "xor"
start_cat = 30
end_cut = 200

# %%
all_results_dict, res_df = get_all_num_features_results(
    res_folder=res_folder,
    end_cut=end_cut,
    time_str=time_str,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='losses',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s test',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s train',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
res_df_800 = pd.read_csv(f"{res_folder}/2023-04-24-18-34-13_feature_selection_final_800.csv", index_col=False).drop(
    "Unnamed: 0", axis=1)

res_df_200 = pd.read_csv(f"{res_folder}/2023-04-24-18-34-13_feature_selection_final_200.csv", index_col=False).drop(
    "Unnamed: 0", axis=1)
res_df_50 = pd.read_csv(f"{res_folder}/2023-04-24-18-34-13_feature_selection_final_50.csv", index_col=False).drop(
    "Unnamed: 0", axis=1)

# %%
tops = []
max_top = 10

# %%
top_800_max = res_df_800.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best max test r2: {top_800_max} avg over last 800 ephocs)")
tops += top_800_max
# Out:
# best max test r2: [85, 96, 95, 90, 65, 80, 70, 75, 55, 60] avg over last 800 ephocs)

# %%
top_800_mean = res_df_800.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best mean test r2: {top_800_mean} avg over last 800 ephocs)")
tops += top_800_mean
# Out:
# best mean test r2: [85, 95, 90, 65, 96, 70, 75, 80, 60, 40] avg over last 800 ephocs)

# %%
top_50_max = res_df_50.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best max test r2: {top_50_max} avg over last 50 ephocs)")
tops += top_50_max
# Out:
# best max test r2: [85, 95, 96, 90, 65, 80, 70, 75, 60, 55] avg over last 50 ephocs)

# %%
top_50_mean = res_df_50.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best mean test r2: {top_50_max} avg over last 50 ephocs)")
tops += top_50_mean
# Out:
# best mean test r2: [85, 95, 96, 90, 65, 80, 70, 75, 60, 55] avg over last 50 ephocs)

# %%
top_200_max = res_df_200.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best max test r2: {top_200_max} avg over last 200 ephocs)")
tops += top_200_max
# Out:
# best max test r2: [95, 85, 96, 90, 65, 70, 80, 75, 60, 55] avg over last 200 ephocs)

# %%
top_200_mean = res_df_200.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best mean test r2: {top_200_mean} avg over last 200 ephocs)")
tops += top_200_mean
# Out:
# best mean test r2: [85, 96, 95, 90, 65, 80, 75, 70, 60, 35] avg over last 200 ephocs)

# %%
tops_set = set(tops)
print(tops_set)
# Out:
# {96, 65, 35, 70, 40, 75, 80, 85, 55, 90, 60, 95}

# %%
desiered_num_features = {'55', '85', '95', '60', '40'}
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=25,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=50,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=15,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
used_features_csv_path = f"{base_path}/teach_archs/xors/xor_lightgbm_feature_selection_2/2023-04-25-13-56-23_used_features.csv"
fig_out_folder = f"xor_regression_feature_selection_2"

# %%
used_features_df = pd.read_csv(used_features_csv_path).drop("Unnamed: 0", axis=1)
sum_uses = used_features_df.sum().sort_index().sort_values(ascending=False)

# %%
cut = 15
is_top = True
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=is_top,
)

# %%
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=False,
)
