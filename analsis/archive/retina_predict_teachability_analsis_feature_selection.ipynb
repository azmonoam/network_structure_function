# %%
from datetime import datetime as dt

import pandas as pd

from utils.plot_utils import plot_all_num_features_models, plot_loss_and_r2s_for_selected_feature_numbers, \
    plot_num_features_vs_r2, plot_bar_plot_of_used_features
from utils.utils import get_all_num_features_results

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/retina/retina_teach_archs_regression_feature_selection_results"
used_features_csv_path = f"{base_path}/teach_archs/retina/retina_lightgbm_feature_selection"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")
fig_out_folder = f"retina_regression_feature_selection_2"
lr = 0.001
task = "retina"
end_cut = 800
start_cat = 30

# %%
all_results_dict, res_df = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=200,
    end_idx=800
)
res_df.to_csv(f"{res_folder}/{time_str}_feature_selection_final_{end_cut}.csv", )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 all_results_dict, res_df = get_all_num_features_results(
#       2     res_folder=res_folder,
#       3     start_idx=200,
#       4     end_idx=800
#       5 )
#       6 res_df.to_csv(f"{res_folder}/{time_str}_feature_selection_final_{end_cut}.csv", )
#
# File ~/PycharmProjects/network_modularity/analsis/teachability/utils/utils.py:16, in get_all_num_features_results(res_folder, start_idx, end_idx)
#      14 res_df = pd.DataFrame()
#      15 all_results_dict = {}
# ---> 16 for i, csv_name in enumerate(os.listdir(res_folder)):
#      17     if csv_name.find('feature_selection') != -1:
#      18         continue
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Volumes/noamaz/modularity//teach_archs/retina/retina_teach_archs_regression_feature_selection_results'

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='losses',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s test',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s train',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
res_df_200 = pd.read_csv(f"{res_folder}/2023-04-24-17-06-06_feature_selection.csv", index_col=False).drop("Unnamed: 0",
                                                                                                          axis=1)
res_df_50 = pd.read_csv(f"{res_folder}/2023-04-24-17-09-20_feature_selection_final_50.csv", index_col=False).drop(
    "Unnamed: 0", axis=1)

# %%
print(f"best mean test r2: "
      f" {res_df.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:3].to_list()} "
      "(avg over last 800 ephocs)")
# Out:
# best mean test r2:  [85, 30, 25] (avg over last 800 ephocs)

# %%
print(f"best max test r2: "
      f" {res_df.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:3].to_list()} "
      "(avg over last 800 ephocs)")
# Out:
# best max test r2:  [25, 30, 20] (avg over last 800 ephocs)

# %%
print(f"best mean test r2: "
      f" {res_df_50.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:3].to_list()} "
      "(avg over last 50 ephocs)")
# Out:
# best mean test r2:  [30, 85, 75] (avg over last 50 ephocs)

# %%
print(f"best max test r2: "
      f" {res_df_50.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:3].to_list()} "
      "(avg over last 50 ephocs)")
# Out:
# best max test r2:  [85, 30, 25] (avg over last 50 ephocs)

# %%
print(f"best mean test r2: "
      f" {res_df_200.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:3].to_list()} "
      "(avg over last 200 ephocs)")
# Out:
# best mean test r2:  [85, 30, 75] (avg over last 200 ephocs)

# %%
print(f"best max test r2: "
      f" {res_df_200.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:3].to_list()} "
      "(avg over last 200 ephocs)")
# Out:
# best max test r2:  [85, 30, 25] (avg over last 200 ephocs)

# %%
desiered_num_features = ['85', '30', '25', '20', '75']
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=25,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=50,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=15,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
desiered_num_features = ['85', '10', '15', '30']
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=12,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
base_path = '/Volumes/noamaz/modularity/'
res_folder = f"{base_path}/teach_archs/retina/retina_teach_archs_regression_feature_selection_results_2"
used_features_csv_path = f"{base_path}/teach_archs/retina/retina_lightgbm_feature_selection_2/2023-04-25-12-22-31_used_features.csv"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")
fig_out_folder = f"retina_regression_feature_selection_2"
lr = 0.001
task = "retina"
start_cat = 30

# %%
end_cut = 200
all_results_dict, res_df_200 = get_all_num_features_results(
    res_folder=res_folder,
    end_cut=end_cut,
)

# %%
res_df.to_csv(f"{res_folder}/{time_str}_feature_selection_final_{end_cut}.csv", )

# %%
plot_num_features_vs_r2(
    res_df=res_df_200,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df_200,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s test',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s train',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
end_cut = 800
all_results_dict, res_df_800 = get_all_num_features_results(
    res_folder=res_folder,
    end_cut=end_cut,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df_800,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df_800,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
end_cut = 50
all_results_dict, res_df_50 = get_all_num_features_results(
    res_folder=res_folder,
    end_cut=end_cut,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df_50,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
plot_num_features_vs_r2(
    res_df=res_df_50,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    end_cut=end_cut,
)

# %%
tops = []
max_top = 10
top_800_max = res_df_800.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best max test r2: {top_800_max} avg over last 800 ephocs)")
tops += top_800_max
top_800_mean = res_df_800.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best mean test r2: {top_800_mean} avg over last 800 ephocs)")
tops += top_800_mean

top_50_max = res_df_50.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best max test r2: {top_50_max} avg over last 50 ephocs)")
tops += top_50_max
top_50_mean = res_df_50.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best mean test r2: {top_50_max} avg over last 50 ephocs)")
tops += top_50_mean
top_200_max = res_df_200.sort_values('max_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best max test r2: {top_200_max} avg over last 200 ephocs)")
tops += top_200_max
top_200_mean = res_df_200.sort_values('mean_test_r2', ascending=False)['num_features'].iloc[0:max_top].to_list()
print(f"best mean test r2: {top_200_mean} avg over last 200 ephocs)")
tops += top_200_mean
tops_set = set(tops)
tops_set
# Out:
# best max test r2: [20, 25, 85, 30, 80, 35, 75, 45, 40, 15] avg over last 800 ephocs)
# best mean test r2: [80, 85, 75, 30, 20, 25, 60, 40, 35, 55] avg over last 800 ephocs)
# best max test r2: [20, 25, 85, 30, 80, 35, 75, 45, 40, 15] avg over last 50 ephocs)
# best mean test r2: [20, 25, 85, 30, 80, 35, 75, 45, 40, 15] avg over last 50 ephocs)
# best max test r2: [20, 25, 85, 30, 80, 35, 75, 45, 40, 15] avg over last 200 ephocs)
# best mean test r2: [80, 75, 30, 85, 20, 45, 25, 35, 60, 40] avg over last 200 ephocs)
# {15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 75, 80, 85}

# %%
desiered_num_features = ['85', '30', '25', '20', '75']
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=25,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=50,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=15,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
desiered_num_features = ['85', '5', '15', '30']
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=12,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
used_features_df = pd.read_csv(used_features_csv_path).drop("Unnamed: 0", axis=1)
sum_uses = used_features_df.sum().sort_index().sort_values(ascending=False)

# %%
cut = 15
is_top = True
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=is_top,
)

# %%
plot_bar_plot_of_used_features(
    sum_uses=sum_uses,
    cut=cut,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    is_top=False,
)
