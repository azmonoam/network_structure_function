# %%
from datetime import datetime as dt

import pandas as pd

from analsis.analsis_utils.plot_utils import plot_all_num_features_models, plot_loss_and_r2s_for_selected_feature_numbers, \
    plot_num_features_vs_r2, plot_bar_plot_of_used_features
from analsis.analsis_utils.utils import get_all_num_features_results

# %%
exp_name = 'exp_2023-04-24-14-47-11'
base_path = '/Volumes/noamaz/modularity'
res_folder = f"{base_path}/teach_archs/retina/retina_lightgbm_feature_selection/{exp_name}/teach_archs_regression_feature_selection_results/2023-04-24-15-13-32_1000_ephocs"
local_base_path = '/Users/noamazmon/PycharmProjects/network_modularity'
time_str = dt.now().strftime("%Y-%m-%d-%H-%M-%S")
fig_out_folder = f"retina_regression_feature_selection/{exp_name}"
lr = 0.001
task = "retina"

# %%
start_idx=200
end_idx=1000
all_results_dict, res_df = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=start_idx,
    end_idx=end_idx
)

# %%
#res_df.to_csv(f"{res_folder}/{time_str}_feature_selection_final_{end_cut}.csv", )

# %%
plot_num_features_vs_r2(
    res_df=res_df,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'ep_{start_idx}_{end_idx}',
)

# %%
plot_num_features_vs_r2(
    res_df=res_df,
    r2_param='max',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'ep_{start_idx}_{end_idx}',
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='losses',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s test',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
plot_all_num_features_models(
    x_label='Epoch',
    y_label='r2s train',
    all_results_dict=all_results_dict,
    cut=15,
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    lr=lr,
)

# %%
start_idx=50
end_idx=250
all_results_dict, res_df = get_all_num_features_results(
    res_folder=res_folder,
    start_idx=50,
    end_idx=250
)

# %%
plot_num_features_vs_r2(
    res_df=res_df,
    r2_param='mean',
    fig_out_folder=fig_out_folder,
    local_base_path=local_base_path,
    time_str=time_str,
    task=task,
    additional_data_txt=f'ep_{start_idx}_{end_idx}',
)

# %%
desiered_num_features = [85, 30, 25, 20, 75]
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=25,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=50,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=15,
    on_end=False,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)

# %%
desiered_num_features = [85, 10, 15, 30]
plot_loss_and_r2s_for_selected_feature_numbers(
    desiered_num_features=desiered_num_features,
    all_results_dict=all_results_dict,
    cut=12,
    on_end=True,
    lr=lr,
    task=task,
    time_str=time_str,
    local_base_path=local_base_path,
    fig_out_folder=fig_out_folder,
)
